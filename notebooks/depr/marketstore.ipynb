# %%
# %load_ext autoreload
# %autoreload 2
from src.data import make_data
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-5e3f25db500f> in <module>
#       1 get_ipython().run_line_magic('load_ext', 'autoreload')
#       2 get_ipython().run_line_magic('autoreload', '2')
# ----> 3 from src.data import make_data
#
# ImportError: cannot import name 'make_data' from 'src.data' (/Users/robin/Documents/nf-ds/capstone/src/data/__init__.py)

# %%
import urllib.request, json 
import pandas as pd
from dotenv import find_dotenv, load_dotenv
# 
import pymarketstore as pymkts

# %%
#env_vars = find_env()
#load_dotenv(env_vars)
load_dotenv(find_dotenv())
# Out:
# True

# %%
ur = 'https://cloud.iexapis.com/beta/ref-data/exchange/ETR/symbols?token=sk_6bf534a90f9444cdaf91c67a27562f3b'
with urllib.request.urlopen(ur) as url:
    data = json.loads(url.read().decode())
    #print(data)

# %%
type(data)
# Out:
# list

# %%
data[148]
# Out:
# {'symbol': 'ADS-GY',
#  'exchange': 'ETR',
#  'name': 'adidas AG',
#  'date': '2019-12-03',
#  'type': 'cs',
#  'iexId': 'IEX_5144595952522D52',
#  'region': 'DE',
#  'currency': 'EUR',
#  'isEnabled': True}

# %%
[i for i in range(len(data)) if data[i]['name'].find('volks') == 0]
# Out:
# []

# %%
list_names = [x['name'] for x in data]
list_symbols = [x['symbol'] for x in data]

# %%
data2 = data

# %%
dic = {data2[i]['symbol']: data2[i] for i in range(len(data2))}

# %%
js = json.dumps(dic)

# %%
df = pd.DataFrame.from_dict(dic)

# %%
df.head()
# Out:
#                         00XJ-GY               00XK-GY               00XM-GY  \
# currency                    EUR                   EUR                   EUR
# date                 2019-12-03            2019-12-03            2019-12-03
# exchange                    ETR                   ETR                   ETR
# iexId      IEX_465250385A522D52  IEX_4742564732382D52  IEX_4D31355251442D52
# isEnabled                  True                  True                  True
#
#                         00XN-GY               00XP-GY               00XR-GY  \
# currency                    EUR                   EUR                   EUR
# date                 2019-12-03            2019-12-03            2019-12-03
# exchange                    ETR                   ETR                   ETR
# iexId      IEX_4D4D425853582D52  IEX_5339503747312D52  IEX_4E53503759592D52
# isEnabled                  True                  True                  True
#
#                         00XS-GY               0GZA-GY               0GZB-GY  \
# currency                    EUR                   EUR                   EUR
# date                 2019-12-03            2019-12-03            2019-12-03
# exchange                    ETR                   ETR                   ETR
# iexId      IEX_5043564631472D52  IEX_5454385846482D52  IEX_534D594C38472D52
# isEnabled                  True                  True                  True
#
#                         0GZC-GY  ...                YOC-GY  \
# currency                    EUR  ...                   EUR
# date                 2019-12-03  ...            2019-12-03
# exchange                    ETR  ...                   ETR
# iexId      IEX_54373352425A2D52  ...  IEX_4A4B484E304A2D52
# isEnabled                  True  ...                  True
#
#                          YSN-GY                ZAL-GY                ZEF-GY  \
# currency                    EUR                   EUR                   EUR
# date                 2019-12-03            2019-12-03            2019-12-03
# exchange                    ETR                   ETR                   ETR
# iexId      IEX_4A5958544E302D52  IEX_504D364B50322D52  IEX_424D473242332D52
# isEnabled                  True                  True                  True
#
#                          ZEG-GY               ZFIN-GY               ZIL2-GY  \
# currency                    EUR                   EUR                   EUR
# date                 2019-12-03            2019-12-03            2019-12-03
# exchange                    ETR                   ETR                   ETR
# iexId      IEX_42563446504C2D52  IEX_4B504C5647532D52  IEX_4A564A3737582D52
# isEnabled                  True                  True                  True
#
#                          ZO1-GY               ZSOL-GY               ZTWN-GY
# currency                    EUR                   EUR                   EUR
# date                 2019-12-03            2019-12-03            2019-12-03
# exchange                    ETR                   ETR                   ETR
# iexId      IEX_524C444732572D52  IEX_48385052514B2D52  IEX_4E42473552302D52
# isEnabled                  True                  True                  True
#
# [5 rows x 1174 columns]

# %%
df2['type'].unique()
# Out:
# array(['et', 'struct', 'cs', 'oef', 'wt', 'ad', 'temp', 'cef', 'ps', '',
#        'gd'], dtype=object)

# %%
df3 = df2[df2['type'] == 'cs']

# %%
df3.shape
# Out:
# (773, 9)

# %%
df3
# Out:
#         currency        date exchange                 iexId isEnabled  \
# 0UB-GY       EUR  2019-12-03      ETR  IEX_44514B4838512D52      True
# 1COV-GY      EUR  2019-12-03      ETR  IEX_47564A32584E2D52      True
# 1FC-GY       EUR  2019-12-03      ETR  IEX_584739464B4B2D52      True
# 1NBA-GY      EUR  2019-12-03      ETR  IEX_4E3244484A502D52      True
# 1P2N-GY      EUR  2019-12-03      ETR  IEX_575A4A3559572D52      True
# 1SI-GY       EUR  2019-12-03      ETR  IEX_513254304D512D52      True
# 1T2-GY       EUR  2019-12-03      ETR  IEX_4448445131422D52      True
# 2FE-GY       EUR  2019-12-03      ETR  IEX_4354464A434A2D52      True
# 2FI-GY       EUR  2019-12-03      ETR  IEX_54394E424C322D52      True
# 2GB-GY       EUR  2019-12-03      ETR  IEX_4837434C42312D52      True
# 2HRA-GY      EUR  2019-12-03      ETR  IEX_52334A4E33392D52      True
# 2KD-GY       EUR  2019-12-03      ETR  IEX_5831334A35392D52      True
# 2M6-GY       EUR  2019-12-03      ETR  IEX_434B5A364B542D52      True
# 2O4-GY       BGN  2019-12-03      ETR  IEX_42524C5846442D52      True
# 2PP-GY       EUR  2019-12-03      ETR  IEX_52374B3736512D52      True
# 2QU-GY       EUR  2019-12-03      ETR  IEX_4C37423750542D52      True
# 3HX-GY       EUR  2019-12-03      ETR  IEX_4C56543431342D52      True
# 3JG-GY       BGN  2019-12-03      ETR  IEX_4C42534C444A2D52      True
# 3RB-GY       EUR  2019-12-03      ETR  IEX_4E355439395A2D52      True
# 3V64-GY      EUR  2019-12-03      ETR  IEX_464E513135392D52      True
# 45DA-GY      EUR  2019-12-03      ETR  IEX_50385A4A4A312D52      True
# 4DS-GY       EUR  2019-12-03      ETR  IEX_4B43383152562D52      True
# 4HV-GY       EUR  2019-12-03      ETR  IEX_5135355354462D52      True
# 4I1-GY       EUR  2019-12-03      ETR  IEX_4448374250352D52      True
# 4IM-GY       BGN  2019-12-03      ETR  IEX_4B58344336422D52      True
# 4JY1-GY      EUR  2019-12-03      ETR  IEX_4D36345754352D52      True
# 4OI-GY       EUR  2019-12-03      ETR  IEX_464B434A4E312D52      True
# 5AB-GY       EUR  2019-12-03      ETR  IEX_465644464C562D52      True
# 5R9-GY       BGN  2019-12-03      ETR  IEX_56314A4D58382D52      True
# 690D-GY      EUR  2019-12-03      ETR  IEX_51563036384E2D52      True
# ...          ...         ...      ...                   ...       ...
# WDI-GY       EUR  2019-12-03      ETR  IEX_5834325158512D52      True
# WDLK-GY      EUR  2019-12-03      ETR  IEX_473947464A442D52      True
# WEG1-GY      EUR  2019-12-03      ETR  IEX_46345056514A2D52      True
# WELA-GY      EUR  2019-12-03      ETR  IEX_4D36315353342D52      True
# WEW-GY       EUR  2019-12-03      ETR  IEX_4A51445351562D52      True
# WGF1-GY      EUR  2019-12-03      ETR  IEX_44374C4E38312D52      True
# WIG1-GY      EUR  2019-12-03      ETR  IEX_504B5643505A2D52      True
# WIN-GY       EUR  2019-12-03      ETR  IEX_4230323636322D52      True
# WL6-GY       EUR  2019-12-03      ETR  IEX_42444D4448422D52      True
# WMT-GY       EUR  2019-12-03      ETR  IEX_424D394847502D52      True
# WSO1-GY      EUR  2019-12-03      ETR  IEX_52434E4B4B512D52      True
# WSU-GY       EUR  2019-12-03      ETR  IEX_52444D37344B2D52      True
# WSV2-GY      EUR  2019-12-03      ETR  IEX_4C44373730582D52      True
# WUG-GY       EUR  2019-12-03      ETR  IEX_5357313442562D52      True
# WUW-GY       EUR  2019-12-03      ETR  IEX_463944314D532D52      True
# XB6-GY       EUR  2019-12-03      ETR  IEX_5053514630582D52      True
# XCA-GY       EUR  2019-12-03      ETR  IEX_425052324D4D2D52      True
# XONA-GY      EUR  2019-12-03      ETR  IEX_503851354C362D52      True
# Y7R-GY       EUR  2019-12-03      ETR  IEX_4B4E534B43352D52      True
# YCP-GY       EUR  2019-12-03      ETR  IEX_50364C4B464D2D52      True
# YOC-GY       EUR  2019-12-03      ETR  IEX_4A4B484E304A2D52      True
# YSN-GY       EUR  2019-12-03      ETR  IEX_4A5958544E302D52      True
# ZAL-GY       EUR  2019-12-03      ETR  IEX_504D364B50322D52      True
# ZEF-GY       EUR  2019-12-03      ETR  IEX_424D473242332D52      True
# ZEG-GY       EUR  2019-12-03      ETR  IEX_42563446504C2D52      True
# ZFIN-GY      EUR  2019-12-03      ETR  IEX_4B504C5647532D52      True
# ZIL2-GY      EUR  2019-12-03      ETR  IEX_4A564A3737582D52      True
# ZO1-GY       EUR  2019-12-03      ETR  IEX_524C444732572D52      True
# ZSOL-GY      EUR  2019-12-03      ETR  IEX_48385052514B2D52      True
# ZTWN-GY      EUR  2019-12-03      ETR  IEX_4E42473552302D52      True
#
#                                                       name region   symbol  \
# 0UB-GY                                        UBS Group AG     DE   0UB-GY
# 1COV-GY                                        Covestro AG     DE  1COV-GY
# 1FC-GY                                             FACC AG     DE   1FC-GY
# 1NBA-GY                         Anheuser-Busch InBev SA/NV     DE  1NBA-GY
# 1P2N-GY                         Prophecy Development Corp.     DE  1P2N-GY
# 1SI-GY                                   Snap Inc. Class A     DE   1SI-GY
# 1T2-GY                        VST Building Technologies AG     DE   1T2-GY
# 2FE-GY                                          Ferrari NV     DE   2FE-GY
# 2FI-GY                      Fiat Chrysler Automobiles N.V.     DE   2FI-GY
# 2GB-GY                                        2G Energy AG     DE   2GB-GY
# 2HRA-GY                                H&R GmbH & Co. KGaA     DE  2HRA-GY
# 2KD-GY                           Kinder Morgan Inc Class P     DE   2KD-GY
# 2M6-GY                                       Medtronic Plc     DE   2M6-GY
# 2O4-GY                                     ONI Holdings AD     DE   2O4-GY
# 2PP-GY                                 PayPal Holdings Inc     DE   2PP-GY
# 2QU-GY                                            onoff AG     DE   2QU-GY
# 3HX-GY                                  Onco Petroleum Inc     DE   3HX-GY
# 3JG-GY                                            Sevko AD     DE   3JG-GY
# 3RB-GY                         Reckitt Benckiser Group plc     DE   3RB-GY
# 3V64-GY                                  Visa Inc. Class A     DE  3V64-GY
# 45DA-GY                                     Ensurapet Inc.     DE  45DA-GY
# 4DS-GY                                 Daldrup & Soehne AG     DE   4DS-GY
# 4HV-GY                         Maple Leaf Green World Inc.     DE   4HV-GY
# 4I1-GY                    Philip Morris International Inc.     DE   4I1-GY
# 4IM-GY                                             IMMI AD     DE   4IM-GY
# 4JY1-GY                                   PT Bank BTPN Tbk     DE  4JY1-GY
# 4OI-GY                      Stratos Renewables Corporation     DE   4OI-GY
# 5AB-GY                                     Asian Bamboo AG     DE   5AB-GY
# 5R9-GY                                     Ruen Holding AD     DE   5R9-GY
# 690D-GY                  Haier Smart Home Co. Ltd. Class D     DE  690D-GY
# ...                                                    ...    ...      ...
# WDI-GY                                         Wirecard AG     DE   WDI-GY
# WDLK-GY                                      windeln.de SE     DE  WDLK-GY
# WEG1-GY                       Westgrund Aktiengesellschaft     DE  WEG1-GY
# WELA-GY                         A.C.N. 059 457 279 Limited     DE  WELA-GY
# WEW-GY                                   Westwing Group AG     DE   WEW-GY
# WGF1-GY                   Williams Grand Prix Holdings PLC     DE  WGF1-GY
# WIG1-GY                                      SPORTTOTAL AG     DE  WIG1-GY
# WIN-GY                                  Diebold Nixdorf AG     DE   WIN-GY
# WL6-GY                                Heidelberg Pharma AG     DE   WL6-GY
# WMT-GY                                        Walmart Inc.     DE   WMT-GY
# WSO1-GY                               wallstreet:online AG     DE  WSO1-GY
# WSU-GY                                          WashTec AG     DE   WSU-GY
# WSV2-GY  Vienna Insurance Group AG Wiener Versicherung ...     DE  WSV2-GY
# WUG-GY                                 Westag & Getalit AG     DE   WUG-GY
# WUW-GY                   Wuestenrot & Wuerttembergische AG     DE   WUW-GY
# XB6-GY                               Xebec Adsorption Inc.     DE   XB6-GY
# XCA-GY                                  Credit Agricole SA     DE   XCA-GY
# XONA-GY                            Exxon Mobil Corporation     DE  XONA-GY
# Y7R-GY                                   YD Ynvisible S.A.     DE   Y7R-GY
# YCP-GY                                      ConocoPhillips     DE   YCP-GY
# YOC-GY                                              YOC AG     DE   YOC-GY
# YSN-GY                        secunet Security Networks AG     DE   YSN-GY
# ZAL-GY                                          Zalando SE     DE   ZAL-GY
# ZEF-GY                         ZhongDe Waste Technology AG     DE   ZEF-GY
# ZEG-GY                                     AstraZeneca PLC     DE   ZEG-GY
# ZFIN-GY                         Zurich Insurance Group Ltd     DE  ZFIN-GY
# ZIL2-GY                                   ElringKlinger AG     DE  ZIL2-GY
# ZO1-GY                                          zooplus AG     DE   ZO1-GY
# ZSOL-GY                                      Solutiance AG     DE  ZSOL-GY
# ZTWN-GY                              Fortune Graphite Inc.     DE  ZTWN-GY
#
#         type
# 0UB-GY    cs
# 1COV-GY   cs
# 1FC-GY    cs
# 1NBA-GY   cs
# 1P2N-GY   cs
# 1SI-GY    cs
# 1T2-GY    cs
# 2FE-GY    cs
# 2FI-GY    cs
# 2GB-GY    cs
# 2HRA-GY   cs
# 2KD-GY    cs
# 2M6-GY    cs
# 2O4-GY    cs
# 2PP-GY    cs
# 2QU-GY    cs
# 3HX-GY    cs
# 3JG-GY    cs
# 3RB-GY    cs
# 3V64-GY   cs
# 45DA-GY   cs
# 4DS-GY    cs
# 4HV-GY    cs
# 4I1-GY    cs
# 4IM-GY    cs
# 4JY1-GY   cs
# 4OI-GY    cs
# 5AB-GY    cs
# 5R9-GY    cs
# 690D-GY   cs
# ...      ...
# WDI-GY    cs
# WDLK-GY   cs
# WEG1-GY   cs
# WELA-GY   cs
# WEW-GY    cs
# WGF1-GY   cs
# WIG1-GY   cs
# WIN-GY    cs
# WL6-GY    cs
# WMT-GY    cs
# WSO1-GY   cs
# WSU-GY    cs
# WSV2-GY   cs
# WUG-GY    cs
# WUW-GY    cs
# XB6-GY    cs
# XCA-GY    cs
# XONA-GY   cs
# Y7R-GY    cs
# YCP-GY    cs
# YOC-GY    cs
# YSN-GY    cs
# ZAL-GY    cs
# ZEF-GY    cs
# ZEG-GY    cs
# ZFIN-GY   cs
# ZIL2-GY   cs
# ZO1-GY    cs
# ZSOL-GY   cs
# ZTWN-GY   cs
#
# [773 rows x 9 columns]

# %%
df2[df2['name'].str.contains('adidas')]
# Out:
#        currency        date exchange                 iexId isEnabled  \
# ADS-GY      EUR  2019-12-03      ETR  IEX_5144595952522D52      True
#
#              name region  symbol type
# ADS-GY  adidas AG     DE  ADS-GY   cs

# %%
# !pwd
# Out:
# /Users/robin/Nextcloud2/Coding/atomm

# %%
cd /Users/robin/Documents/projects/python/test/
# Out:
# /Users/robin/Documents/projects/python/test

# %%
pwd
# Out:
# '/Users/robin/Documents/projects/python/test'

# %%
import pickle

# %%
pickle.dump(df.T, open('iex_symbols_xetra.pkl', 'wb'))

# %%
pkl_df = pickle.load(open('iex_symbols_xetra.pkl', 'rb'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-124-36b2888be43b> in <module>()
# ----> 1 pkl_df = pickle.load(open('iex_symbols_xetra.pkl', 'rb')& (pkl_df['type'] == 'cs'))
#
# ~/anaconda3/envs/atomm/lib/python3.7/site-packages/pandas/core/ops.py in wrapper(self, other)
#    1839                 # could the is_integer_dtype check be checking the wrong
#    1840                 # thing?  e.g. other = [[0, 1], [2, 3], [4, 5]]?
# -> 1841                 other = construct_1d_object_array_from_listlike(other)
#    1842
#    1843             ovalues = other
#
# ~/anaconda3/envs/atomm/lib/python3.7/site-packages/pandas/core/dtypes/cast.py in construct_1d_object_array_from_listlike(values)
#    1211     # numpy will try to interpret nested lists as further dimensions, hence
#    1212     # making a 1D array that contains list-likes is a bit tricky:
# -> 1213     result = np.empty(len(values), dtype='object')
#    1214     result[:] = values
#    1215     return result
#
# TypeError: object of type '_io.BufferedReader' has no len()

# %%
pkl_df[(pkl_df['name'].str.contains('Deutsche')) & (pkl_df['type'] == 'cs')]
# Out:
#         currency        date exchange                 iexId isEnabled  \
# DB1-GY       EUR  2019-12-03      ETR  IEX_5254365736352D52      True
# DBAN-GY      EUR  2019-12-03      ETR  IEX_4C47424B4E372D52      True
# DBK-GY       EUR  2019-12-03      ETR  IEX_5336514C50312D52      True
# DEF-GY       EUR  2019-12-03      ETR  IEX_4A4D424458462D52      True
# DEQ-GY       EUR  2019-12-03      ETR  IEX_543637584A342D52      True
# DFTK-GY      EUR  2019-12-03      ETR  IEX_514833334B472D52      True
# DFV-GY       EUR  2019-12-03      ETR  IEX_5347304B344D2D52      True
# DGR-GY       EUR  2019-12-03      ETR  IEX_564D4A4E4E462D52      True
# DKG-GY       EUR  2019-12-03      ETR  IEX_5432503554512D52      True
# DMRE-GY      EUR  2019-12-03      ETR  IEX_4C39565632312D52      True
# DPW-GY       EUR  2019-12-03      ETR  IEX_56335232585A2D52      True
# DR0-GY       EUR  2019-12-03      ETR  IEX_4A48374D4C592D52      True
# DTE-GY       EUR  2019-12-03      ETR  IEX_444D584B4A422D52      True
# DWNI-GY      EUR  2019-12-03      ETR  IEX_4D42535231312D52      True
# EFF-GY       EUR  2019-12-03      ETR  IEX_4D5236564A472D52      True
# HEMP-GY      EUR  2019-12-03      ETR  IEX_4E374C5757502D52      True
# JB7-GY       EUR  2019-12-03      ETR  IEX_4A424B4332342D52      True
# LHA-GY       EUR  2019-12-03      ETR  IEX_4A30434C35342D52      True
# LOUD-GY      EUR  2019-12-03      ETR  IEX_4A50563244502D52      True
# PBB-GY       EUR  2019-12-03      ETR  IEX_4B30505259322D52      True
#
#                                                       name region   symbol  \
# DB1-GY                                  Deutsche Boerse AG     DE   DB1-GY
# DBAN-GY                           Deutsche Beteiligungs AG     DE  DBAN-GY
# DBK-GY                                    Deutsche Bank AG     DE   DBK-GY
# DEF-GY                        DEFAMA Deutsche Fachmarkt AG     DE   DEF-GY
# DEQ-GY                                Deutsche EuroShop AG     DE   DEQ-GY
# DFTK-GY                             DF Deutsche Forfait AG     DE  DFTK-GY
# DFV-GY                DFV Deutsche Familienversicherung AG     DE   DFV-GY
# DGR-GY                    Deutsche Grundstucksauktionen AG     DE   DGR-GY
# DKG-GY                             Deutsche Konsum REIT-AG     DE   DKG-GY
# DMRE-GY         DEMIRE Deutsche Mittelstand Real Estate AG     DE  DMRE-GY
# DPW-GY                                    Deutsche Post AG     DE   DPW-GY
# DR0-GY                                Deutsche Rohstoff AG     DE   DR0-GY
# DTE-GY                                 Deutsche Telekom AG     DE   DTE-GY
# DWNI-GY                                 Deutsche Wohnen SE     DE  DWNI-GY
# EFF-GY   Deutsche Effecten- und Wechsel-Beteiligungsges...     DE   EFF-GY
# HEMP-GY                               Deutsche Cannabis AG     DE  HEMP-GY
# JB7-GY                          Deutsche Industrie REIT-AG     DE   JB7-GY
# LHA-GY                               Deutsche Lufthansa AG     DE   LHA-GY
# LOUD-GY     DEAG Deutsche Entertainment Aktiengesellschaft     DE  LOUD-GY
# PBB-GY                          Deutsche Pfandbriefbank AG     DE   PBB-GY
#
#         type
# DB1-GY    cs
# DBAN-GY   cs
# DBK-GY    cs
# DEF-GY    cs
# DEQ-GY    cs
# DFTK-GY   cs
# DFV-GY    cs
# DGR-GY    cs
# DKG-GY    cs
# DMRE-GY   cs
# DPW-GY    cs
# DR0-GY    cs
# DTE-GY    cs
# DWNI-GY   cs
# EFF-GY    cs
# HEMP-GY   cs
# JB7-GY    cs
# LHA-GY    cs
# LOUD-GY   cs
# PBB-GY    cs

# %% [markdown]
# # Storing historical US stock data to MarketStore DB

# %%
import pymarketstore as pymkts
import numpy as np
import pandas as pd
import datetime as dt

# %%
data = np.array([(pd.Timestamp('2017-01-01 00:00').value / 10**9, 10.0)], dtype=[('Epoch', 'i8'), ('Open', 'f4')])

# %%
data
# Out:
# array([(1483228800, 10.)], dtype=[('Epoch', '<i8'), ('Ask', '<f4')])

# %%
df = pd.read_csv('/Users/robin/Documents/nf-ds/capstone_nf/data/raw/Data/Stocks/aapl.us.txt', parse_dates=True, index_col='Date')

# %%
# Out:
#                Open     High      Low    Close    Volume  OpenInt
# Date
# 1984-09-07  0.42388  0.42902  0.41874  0.42388  23220030        0
# 1984-09-10  0.42388  0.42516  0.41366  0.42134  18022532        0
# 1984-09-11  0.42516  0.43668  0.42516  0.42902  42498199        0
# 1984-09-12  0.42902  0.43157  0.41618  0.41618  37125801        0
# 1984-09-13  0.43927  0.44052  0.43927  0.43927  57822062        0

# %%
df.tail()
# Out:
#               Open    High     Low   Close    Volume  OpenInt
# Date
# 2017-11-06  171.75  174.36  171.10  173.63  34901241        0
# 2017-11-07  173.29  174.51  173.29  174.18  24424877        0
# 2017-11-08  174.03  175.61  173.71  175.61  24451166        0
# 2017-11-09  174.48  175.46  172.52  175.25  29533086        0
# 2017-11-10  175.11  175.38  174.27  174.67  25130494        0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 8364 entries, 1984-09-07 to 2017-11-10
# Data columns (total 6 columns):
# Open       8364 non-null float64
# High       8364 non-null float64
# Low        8364 non-null float64
# Close      8364 non-null float64
# Volume     8364 non-null int64
# OpenInt    8364 non-null int64
# dtypes: float64(4), int64(2)
# memory usage: 457.4 KB

# %%
df.index[0]
# Out:
# Timestamp('1984-09-07 00:00:00')

# %%
df
# Out:
#                Open     High      Low    Close     Volume  OpenInt
# Date
# 1984-09-07  0.42388  0.42902  0.41874  0.42388   23220030        0
# 1984-09-10  0.42388  0.42516  0.41366  0.42134   18022532        0
# 1984-09-11  0.42516  0.43668  0.42516  0.42902   42498199        0
# 1984-09-12  0.42902  0.43157  0.41618  0.41618   37125801        0
# 1984-09-13  0.43927  0.44052  0.43927  0.43927   57822062        0
# ...             ...      ...      ...      ...        ...      ...
# 1999-12-30  3.27190  3.33360  3.19000  3.21170   57768951        0
# 1999-12-31  3.23090  3.29380  3.18620  3.29120   45684169        0
# 2000-01-03  3.35770  3.60110  3.25540  3.58330  149424648        0
# 2000-01-04  3.46520  3.54220  3.23990  3.28100  142893423        0
# 2000-01-05  3.32200  3.53970  3.29760  3.32950  217060697        0
#
# [3874 rows x 6 columns]

# %%
data = np.array([(pd.Timestamp('20-01-01 00:00').value / 10**9, 10.0)], dtype=[('Epoch', 'i8'), ('Ask', 'f4')])

# %%
da = df.loc[:pd.Timestamp(year=2014, month=12, day=9)].copy()

# %%
da.tail()
# Out:
#               Open    High     Low   Close    Volume  OpenInt
# Date
# 2014-12-03  109.57  110.14  108.98  109.73  45449566        0
# 2014-12-04  109.58  110.95  109.14  109.34  44522535        0
# 2014-12-05  109.79  109.88  108.52  108.87  40469204        0
# 2014-12-08  108.00  108.52  105.67  106.39  60872177        0
# 2014-12-09  104.32  108.20  103.52  108.02  63577767        0

# %%
data = np.array([(da.index[i].value / 10**9, da['Open'][i], da['High'][i],da['Low'][i], da['Close'][i], da['Volume'][i]) for i in range(len(da))],
                 dtype=[('Epoch', 'i8'), ('Open', 'f4'), ('High', 'f4'), ('Low', 'f4'), ('Close', 'f4'), ('Volume', 'i8')])

# %%
data
# Out:
# array([( 463363200,   0.42388,   0.42902,   0.41874,   0.42388, 23220030),
#        ( 463622400,   0.42388,   0.42516,   0.41366,   0.42134, 18022532),
#        ( 463708800,   0.42516,   0.43668,   0.42516,   0.42902, 42498199),
#        ...,
#        (1417392000, 112.47   , 112.89   , 105.32   , 108.94   , 88523014),
#        (1417478400, 107.44   , 109.57   , 106.74   , 108.51   , 62668871),
#        (1417564800, 109.57   , 110.14   , 108.98   , 109.73   , 45449566)],
#       dtype=[('Epoch', '<i8'), ('Open', '<f4'), ('High', '<f4'), ('Low', '<f4'), ('Close', '<f4'), ('Volume', '<i8')])

# %%
# Importing the atomm project specific libraries
from atomm.Indicators import MomentumIndicators
from atomm.DataManager.main import MSDataManager

# %%
dm = MSDataManager()

# %%
dm.ReturnData('AAPL', limit=None)
# Out:
#                                  Open        High         Low       Close  \
# Epoch
# 2014-12-03 00:00:00+00:00  115.750000  116.349998  115.110001  115.930000
# 2014-12-04 00:00:00+00:00  115.769997  117.199997  115.290001  115.489998
# 2014-12-05 00:00:00+00:00  115.989998  116.080002  114.639999  115.000000
# 2014-12-08 00:00:00+00:00  114.099998  114.650002  111.620003  112.400002
# 2014-12-09 00:00:00+00:00  110.190002  114.300003  109.349998  114.120003
# ...                               ...         ...         ...         ...
# 2019-11-27 00:00:00+00:00  265.579987  267.980011  265.309998  267.839996
# 2019-11-29 00:00:00+00:00  266.600006  268.000000  265.899994  267.250000
# 2019-12-02 00:00:00+00:00  267.269989  268.250000  263.450012  264.160004
# 2019-12-03 00:00:00+00:00  258.309998  259.529999  256.290009  259.450012
# 2019-12-04 00:00:00+00:00  261.070007  263.309998  260.679993  261.739990
#
#                              Volume
# Epoch
# 2014-12-03 00:00:00+00:00  43063440
# 2014-12-04 00:00:00+00:00  42155776
# 2014-12-05 00:00:00+00:00  38318895
# 2014-12-08 00:00:00+00:00  57664850
# 2014-12-09 00:00:00+00:00  60208036
# ...                             ...
# 2019-11-27 00:00:00+00:00  16386122
# 2019-11-29 00:00:00+00:00  11654363
# 2019-12-02 00:00:00+00:00  23693550
# 2019-12-03 00:00:00+00:00  29377268
# 2019-12-04 00:00:00+00:00  16810388
#
# [1260 rows x 5 columns]

# %%
df2 = pd.read_csv('/Users/robin/Documents/nf-ds/capstone_nf/data/raw/historical_stock_prices.csv')

# %%
aapl = df2[df2['ticker'] == 'AAPL'].copy()

# %%
aapl.set_index('date', inplace=True,)

# %%
aapl.index = [pd.Timestamp(x) for x in aapl.index]

# %%
aapl.index
# Out:
# DatetimeIndex(['1980-12-12', '1980-12-15', '1980-12-16', '1980-12-17',
#                '1980-12-18', '1980-12-19', '1980-12-22', '1980-12-23',
#                '1980-12-24', '1980-12-26',
#                ...
#                '2018-08-13', '2018-08-14', '2018-08-15', '2018-08-16',
#                '2018-08-17', '2018-08-20', '2018-08-21', '2018-08-22',
#                '2018-08-23', '2018-08-24'],
#               dtype='datetime64[ns]', length=9507, freq=None)

# %%
aapl_kg1 = aapl.loc[:pd.Timestamp(year=2014, month=12, day=2)].copy()

# %%
aapl_kg1
# Out:
#            ticker        open       close   adj_close         low        high  \
# 1980-12-12   AAPL    0.513393    0.513393    0.023186    0.513393    0.515625
# 1980-12-15   AAPL    0.488839    0.486607    0.021977    0.486607    0.488839
# 1980-12-16   AAPL    0.453125    0.450893    0.020364    0.450893    0.453125
# 1980-12-17   AAPL    0.462054    0.462054    0.020868    0.462054    0.464286
# 1980-12-18   AAPL    0.475446    0.475446    0.021473    0.475446    0.477679
# ...           ...         ...         ...         ...         ...         ...
# 2014-11-25   AAPL  119.070000  117.599998  110.059097  117.449997  119.750000
# 2014-11-26   AAPL  117.940002  119.000000  111.369316  117.830002  119.099998
# 2014-11-28   AAPL  119.269997  118.930000  111.303802  118.050003  119.400002
# 2014-12-01   AAPL  118.809998  115.070000  107.691330  111.269997  119.250000
# 2014-12-02   AAPL  113.500000  114.629997  107.279541  112.750000  115.750000
#
#                volume
# 1980-12-12  117258400
# 1980-12-15   43971200
# 1980-12-16   26432000
# 1980-12-17   21610400
# 1980-12-18   18362400
# ...               ...
# 2014-11-25   68840400
# 2014-11-26   40768300
# 2014-11-28   24814400
# 2014-12-01   83814000
# 2014-12-02   59348900
#
# [8568 rows x 7 columns]

# %%
df2 = pd.read_csv('/Users/robin/Documents/nf-ds/capstone_nf/data/raw/historical_stock_prices.csv')
djia_symbols_list = ['AAPL', 'AXP', 'BA', 'CAT', 'CSCO', 'CVX', 'DIS', 'DOW', 'GS', 'HD', 'IBM', 'INTC', 'JNJ', 'JPM', 'KO', 'MCD', 'MMM', 'MRK', 'MSFT', 'NKE', 'PFE', 'PG', 'TRV', 'UNH', 'UTX', 'V', 'VZ', 'WBA', 'WMT', 'XOM']

# %%
len(df2['ticker'].unique())
# Out:
# 5685

# %%
df2_descr = pd.read_csv('/Users/robin/Documents/nf-ds/capstone_nf/data/raw/historical_stocks.csv')

# %%
df2_descr['exchange']
# Out:
# array(['NASDAQ', 'NYSE'], dtype=object)

# %%
df2_descr['ticker'].shape
# Out:
# (6460,)

# %%
## Dow Jones Industrial Average

# %%
for symb in djia_symbols_list:
    df = df2[df2['ticker'] == symb].copy()
    df.set_index('date', inplace=True,)
    df.index = [pd.Timestamp(x) for x in df.index]
    df_kg1 = df.loc[:pd.Timestamp(year=2014, month=12, day=2)].copy()
    data = np.array([(df_kg1.index[i].value / 10**9, df_kg1['open'][i], df_kg1['high'][i], df_kg1['low'][i], df_kg1['close'][i], df_kg1['volume'][i]) for i in range(len(df_kg1))],
                     dtype=[('Epoch', 'i8'), ('Open', 'f4'), ('High', 'f4'), ('Low', 'f4'), ('Close', 'f4'), ('Volume', 'i4')])
    cli.write(data, symb+'/1D/OHLCV')

# %%
## S&P 500

import json
import urllib.request
import urllib

# %%
sp500_symbols_list = pd.read_csv('https://datahub.io/core/s-and-p-500-companies/r/constituents.csv')

# %%
sp500_symbols_list['Symbol'].nunique()
# Out:
# 505

# %%
sp500_symbols_list_2 = [x for x in sp500_symbols_list['Symbol'].to_list() if x in df2_descr['ticker'].to_list()]

# %%
[x for x in sp500_symbols_list['Symbol'].to_list() if x not in sp500_symbols_list_2]
# Out:
# ['CSRA']

# %%
cli = pymkts.Client('http://atomm.de:5993/rpc')
for symb in sp500_symbols_list['Symbol'].to_list():
    df = df2[df2['ticker'] == symb].copy()
    df.set_index('date', inplace=True,)
    df.index = [pd.Timestamp(x) for x in df.index]
    df_kg1 = df.copy()
    data = np.array([(df_kg1.index[i].value / 10**9, df_kg1['open'][i], df_kg1['high'][i], df_kg1['low'][i], df_kg1['close'][i], df_kg1['volume'][i]) for i in range(len(df_kg1))],
                     dtype=[('Epoch', 'i8'), ('Open', 'f4'), ('High', 'f4'), ('Low', 'f4'), ('Close', 'f4'), ('Volume', 'i4')])
    cli.write(data, symb+'/1D/OHLCV')

# %%
cli = pymkts.Client('http://atomm.de:5993/rpc')

# %%
ms_symbols_list = cli.list_symbols()

# %%
missing_symbols = [x for x in sp500_symbols_list if x not in ms_symbols_list]
missing_symbols
# Out:
# ['Symbol', 'Name', 'Sector']

# %%
'TEST' in ms_symbols_list
# Out:
# True

# %%
axp = dm.ReturnData('AXP', limit=None)

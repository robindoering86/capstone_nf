# %%
# %load_ext autoreload
# %autoreload 2

# %%
# Importing the atomm project specific libraries
from atomm.Indicators import MomentumIndicators
from atomm.DataManager.main import MSDataManager

# %%
# Pandas and numpy
import pandas as pd
import numpy as np

# Libraries for Visualization
import matplotlib.pyplot as plt
import seaborn

# Alpaca API
import alpaca_trade_api as tradeapi

# Pickle
import pickle

# %%
from dotenv import find_dotenv, load_dotenv
load_dotenv(find_dotenv())
# Out:
# True

# %%
### NOTE: In a later version, the the data download part will be outsourced to a separate script.

dm = MSDataManager()

# %%
djia_symbols_list = ['AAPL', 'AXP', 'BA', 'CAT', 'CSCO', 'CVX', 'DIS', 'DOW', 'GS', 'HD', 'IBM', 'INTC', 'JNJ', 'JPM', 'KO', 'MCD', 'MMM', 'MRK', 'MSFT', 'NKE', 'PFE', 'PG', 'TRV', 'UNH', 'UTX', 'V', 'VZ', 'WBA', 'WMT', 'XOM']

# For starters, we will look at 5 years of DOW JONES DATA

# %%
# Obtain 5 years of historical data for Microsoft
# Get daily price data for AAPL over the last 5 trading days.
api = tradeapi.REST()
djia0 = api.get_barset(djia_symbols_list+['DJIA'], 'day', limit=1000).df

# %%
djia0.head()
# Out:
#                              AAPL                                        \
#                              open    high     low     close      volume
# time
# 2015-12-15 05:00:00+00:00     NaN     NaN     NaN       NaN         NaN
# 2015-12-16 05:00:00+00:00     NaN     NaN     NaN       NaN         NaN
# 2015-12-17 05:00:00+00:00  112.02  112.17  108.99  108.9999  39052007.0
# 2015-12-18 05:00:00+00:00  108.91  109.52  105.81  105.9500  60812399.0
# 2015-12-21 05:00:00+00:00  107.28  107.37  105.57  107.3200  37995834.0
#
#                              AXP                                   ...    WMT  \
#                             open   high    low  close      volume  ...   open
# time                                                               ...
# 2015-12-15 05:00:00+00:00    NaN    NaN    NaN    NaN         NaN  ...    NaN
# 2015-12-16 05:00:00+00:00    NaN    NaN    NaN    NaN         NaN  ...    NaN
# ...

# %%
# pickle the raw data 


pickle.dump(djia0, open(b'djia_raw_2019-12-09.pkl', 'wb'))

# %%
# Instantiate a MomentumIndicators() class object
mi = MomentumIndicators(df['Close'])

# Calculates the Moving Average Convergence-Divergence 
macd = mi.calcMACD(9, 20)

# %%
imp

# %%
import datetime as dt
end_date = dt.datetime(2019, 12, 6)

# %%
aapl = dm.ReturnData('AAPL', end_date=end_date, limit=None)
msft = dm.ReturnData('MSFT', limit=None)

# %%
df_conc = pd.concat([aapl, msft], axis=1)

# %%
df_conc.head()
# Out:
#                                  Open        High         Low       Close  \
# Epoch
# 2014-12-03 00:00:00+00:00  115.750000  116.349998  115.110001  115.930000
# 2014-12-04 00:00:00+00:00  115.769997  117.199997  115.290001  115.489998
# 2014-12-05 00:00:00+00:00  115.989998  116.080002  114.639999  115.000000
# 2014-12-08 00:00:00+00:00  114.099998  114.650002  111.620003  112.400002
# 2014-12-09 00:00:00+00:00  110.190002  114.300003  109.349998  114.120003
#
#                              Volume       Open       High        Low  \
# Epoch
# 2014-12-03 00:00:00+00:00  43063440        NaN        NaN        NaN
# 2014-12-04 00:00:00+00:00  42155776        NaN        NaN        NaN
# 2014-12-05 00:00:00+00:00  38318895  48.820000  48.970001  48.380001
# 2014-12-08 00:00:00+00:00  57664850  48.259998  48.349998  47.450001
# 2014-12-09 00:00:00+00:00  60208036  47.110001  47.919998  47.049999
#
#                                Close      Volume
# Epoch
# ...

# %%
df_conc.shape
# Out:
# (2518, 5)

# %% [markdown]
# **TODO: Outsource this to a description file**
# * Open / High / Low / Close / Volume: The standard set of market data for stock, where Open is the opening price for the given timeframe (in this case: daily), high and loware  the (daily) highs and lows, while close is the last price at market close. Volume denotes the volume traded.
# * Daily Returns: The daily returns on a specific symbol
# * MACD
# * ROC
# * RSI
# * EMA
# * STOC
# * ATR
